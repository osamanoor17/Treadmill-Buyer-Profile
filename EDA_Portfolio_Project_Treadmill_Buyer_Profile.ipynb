# %% [markdown]
# <a href="https://colab.research.google.com/github/osamanoor17/Treadmill-Buyer-Profile/blob/main/EDA_Portfolio_Project_Treadmill_Buyer_Profile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EDA Portfolio Project - Treadmill Buyer Profile

# %%
# importing libraries
import numpy as np
import pandas as pd

# %%
# Mount the file from google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read csv file
data = pd.read_csv("/content/drive/MyDrive/aerofit_treadmill_data (2).csv")

# %%
# exploring the data..
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
# Reading the dataframe (viewing the first 10 rows)
data.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47
# 5   KP281   20  Female         14     Partnered      3        3   32973     66
# 6   KP281   21  Female         14     Partnered      3        3   35247     75
# 7   KP281   21    Male         13        Single      3        3   32973     85
# 8   KP281   21    Male         15        Single      5        4   35247    141
# 9   KP281   21  Female         15     Partnered      2        3   37521     85

# %% [markdown]
# *** Data Exploration and Processing:***

# %%
#  Checking the shape of the dataframe
data.shape # (rows,columns)
# Out:
# (180, 9)

# %%
# data types of the dataset
data.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
# detection of missing values in dataset
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# detection of duplicates values in dataset
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ***Statistical Summary: ***

# %%
# Provide an analysis of the statistical summary in few lines for both categorical and numerical features.
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
# Statistical Summary for Categorical Features
data.describe(include='object')
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %%
data.describe(include='int')
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# ***Non-Graphical Analysis:***

# %%
data.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object', name='Features')

# %%
# Value Counts for all categorical features
data['Gender'].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
data[['Product', 'Gender', 'MaritalStatus']].value_counts()
# Out:
# Product  Gender  MaritalStatus
# KP281    Female  Partnered        27
#          Male    Partnered        21
# KP481    Male    Partnered        21
# KP281    Male    Single           19
# KP781    Male    Partnered        19
# KP481    Female  Partnered        15
#                  Single           14
# KP781    Male    Single           14
# KP281    Female  Single           13
# KP481    Male    Single           10
# KP781    Female  Partnered         4
#                  Single            3
# Name: count, dtype: int64

# %%
# Unique Attributes for all categorical features
data[['Product', 'Gender', 'MaritalStatus']].apply(lambda x: x.unique())
# Out:
# Product          [KP281, KP481, KP781]
# Gender                  [Male, Female]
# MaritalStatus      [Single, Partnered]
# dtype: object

# %%
# Unique Attributes for all categorical features
for col in data.select_dtypes(include=['object']).columns:
    print(f"Unique values for {col}: {data[col].unique()}")
# Out:
# Unique values for Product: ['KP281' 'KP481' 'KP781']
# Unique values for Gender: ['Male' 'Female']
# Unique values for MaritalStatus: ['Single' 'Partnered']

# %% [markdown]
# ***Graphical Analysis:***

# %%
# importing more libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Univariate Analysis - Numerical features:
numerical_values = data.select_dtypes(include=['float64','int64']).columns

# %%
for numerical_values in numerical_values:
    plt.figure(figsize=(12, 10))
    sns.histplot(data[numerical_values], bins=20, kde=True,color=sns.color_palette("husl", 8)[0])
    plt.title(f'Distribution of {numerical_values}')
    plt.xlabel(numerical_values)

# %%
# Count Plot (For Discrete Numerical Features)
plt.figure(figsize=(15, 12))
num_cols = data.select_dtypes(include=np.number).columns

for i, col in enumerate(num_cols):
    plt.subplot(3, 2, i + 1)
    sns.countplot(x=data[col], color=sns.color_palette("husl")[2])
    plt.title(f'Count of {col}')
    plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#  Box Plot (Detecting the Outliers)
plt.figure(figsize=(12, 10))
num_cols = data.select_dtypes(include=np.number).columns

for i, col in enumerate(num_cols):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(y=data[col], color=sns.color_palette("husl")[3])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
# Univariate Analysis - Categorical features:
categorical_values = data.select_dtypes(include=['object']).columns

# %%
# Count Plot
for categorical_values in categorical_values:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=data, x=categorical_values)
    plt.title(f'Count Plot of {categorical_values}')
    plt

# %% [markdown]
# # Bivariate Analysis:
# # Check features effect on the product purchased e.g. ***bold text***

# %%
  # Product vs Gender
plt.figure(figsize=(8, 6))
sns.countplot(x="Product", hue="Gender", data=data,palette= sns.color_palette("husl"))
plt.title("Product vs Gender")
plt.show()
# Out:
# <ipython-input-55-8a6447097ce5>:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.countplot(x="Product", hue="Gender", data=data,palette= sns.color_palette("husl"))

# %%
# Product vs Marital Status
plt.figure(figsize=(6, 4))
sns.countplot(x="Product", hue="MaritalStatus", data=data, palette="coolwarm")
plt.title("Product vs Marital Status")
plt.show()

# %%
# Product vs Age
plt.figure(figsize=(8, 5))
sns.violinplot(data=data, x='Product', y='Age', hue='Product')
plt.title("Product vs Age")
plt.show()

# %% [markdown]
# ***Multivariate Analysis: ***

# %%
# Create pairplots to show relationship of features
sns.pairplot(data, hue='Age')
plt.show()

# Using a scatter plot for more control
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='Age', y='Income', hue='Product')
plt.title('Age vs. Income with Product as Hue')
plt.show()

# %% [markdown]
# ***Correlation Analysis:***

# %%
# Show the correlation matrix on heatmap and write your observation of findings in few lines.
plt.figure(figsize=(10,8))
corr_matrix = data.select_dtypes(include='number').corr()
sns.heatmap(corr_matrix,annot=True, cmap="crest",fmt=".1f")
plt.show()

# %% [markdown]
# ***Outlier Detection:***

# %%
# Check for the outliers by using the IQR method.

outliers = {}

for col in data.select_dtypes(include='number').columns:
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    IQR = q3 - q1
    upper_limit = q3 + 1.5 * IQR
    lower_limit = q1 - 1.5 * IQR

    outlier_values = data[(data[col] > upper_limit) | (data[col] < lower_limit)][col]

    outliers[col] = outlier_values.tolist()

    print(f"\nColumn: {col}")
    print(f"Upper Limit: {upper_limit}, Lower Limit: {lower_limit}")
    print(f"Outliers: {outlier_values.tolist()}")
# Out:
# Column: Age
# Upper Limit: 46.5, Lower Limit: 10.5
# Outliers: [47, 50, 48, 47, 48]
#
# Column: Education
# Upper Limit: 19.0, Lower Limit: 11.0
# Outliers: [20, 21, 21, 21]
#
# Column: Usage
# Upper Limit: 5.5, Lower Limit: 1.5
# Outliers: [6, 6, 6, 7, 6, 7, 6, 6, 6]
#
# Column: Fitness
# Upper Limit: 5.5, Lower Limit: 1.5
# Outliers: [1, 1]
#
# Column: Income
# Upper Limit: 80581.875, Lower Limit: 22144.875
# Outliers: [83416, 88396, 90886, 92131, 88396, 85906, 90886, 103336, 99601, 89641, 95866, 92131, 92131, 104581, 83416, 89641, 90886, 104581, 95508]
#
# Column: Miles
# Upper Limit: 187.875, Lower Limit: -7.125
# Outliers: [188, 212, 200, 200, 200, 240, 300, 280, 260, 200, 360, 200, 200]

# %% [markdown]
# *** Conditional Probabilities: ***

# %%
# What percent of customers have purchased KP281, KP481, or KP781?

selected_products = ['KP281', 'KP481', 'KP781']
customers_with_selected_products = data[data['Product'].isin(selected_products)]

# Calculating the percentage
percentage = (len(customers_with_selected_products) / len(data)) * 100

print(f"Percentage of customers who purchased KP281, KP481, or KP781: {percentage:.2f}%")
# Out:
# Percentage of customers who purchased KP281, KP481, or KP781: 100.00%

# %% [markdown]
# **Create frequency tables and calculate the percentage as follows**
# - **Product – Gender**
#     - Percentage of a Male customer purchasing a treadmill
#     - Percentage of a Female customer purchasing KP781 treadmill
#     - Probability of a customer being a Female given that Product is KP281
# - **Product – Age**
#     - Percentage of customers with Age between 20s and 30s among all customers
# - **Product – Income**
#     - Percentage of a low-income customer purchasing a treadmill
#     - Percentage of a high-income customer purchasing KP781 treadmill
#     - Percentage of customer with high-income salary buying treadmill given that Product is KP781
#
#       - **Income table is right skewed so i split income based on quartile**
#         - Low Income: Below the 25th percentile (Q1) → Income < 44,058.75
#         - Middle Income: Between Q1 and Q3 (44,058.75 to 58,668.00)
#         - High Income: Above the 75th percentile (Q3) → Income > 58,668.00
# - **Product – Fitness**
#     - Percentage of customers that have fitness level 5
#     - Percentage of a customer with Fitness Level 5 purchasing KP781 treadmill
#     - Percentage of customer with fitness level 5 buying KP781 treadmill
# - **Product - Marital Status**
#     - Percentage of a customers who are partnered using treadmills

# %%
from IPython.core.display import display, HTML
display(HTML("<b>Product - Gender:</b>"))
# Total number of customers
total_customers = data['Gender'].count()
print(f'Total number of customers is: {total_customers}')

# Count of male
count_of_male=(data['Gender']=='Male').sum()
print(f'\nThe count of Male customers is: {count_of_male}')

# Percentage of Male customers purchasing a treadmill
percentage_male = (count_of_male / total_customers ) * 100
print(f'The percentage of Male customers purchasing a treadmill is: {percentage_male:.2f}%')

# Count of a Female customer purchasing KP781 treadmill
count_of_female_KP781 = data[(data['Gender'] == 'Female') & (data['Product'] == 'KP781')]['Gender'].count()
print(f'\nThe count of female purchasing KP781 treadmill is: {count_of_female_KP781}')

# Percentage of Female customers purchasing KP781 treadmill
percentage_female = (count_of_female_KP781 / total_customers) * 100
print(f'The percentage of Female customers purchasing a KP781 treadmill is: {percentage_female:.2f}%')

# Total no of pruchasing KP281 treadmill is
total_KP281 = (data['Product'] == 'KP281').sum()
print(f'\nThe total no of pruchasing KP281 treadmill is: {total_KP281}')

#count of Female purchasing KP281 treadmill is
count_of_female_KP281 = data[(data['Gender']== 'Female') & (data['Product'] == 'KP281')]['Gender'].count()
print(f'The count of Female purchasing KP281 treadmill is: {count_of_female_KP281}')

# Probability of a customer being Female given that they purchased KP281 treadmill
prob_female_given_KP281 = count_of_female_KP281 / total_KP281 if total_KP281 != 0 else 0
print(f'The probablity of a customer being a Female given that product is KP281 is: {prob_female_given_KP281:.2f}')

display(HTML("<b>Product - Age:</b>"))
# Count customers Age between 20 to 30
age_20_30 = data[(data['Age'] >= 20) & (data['Age'] <= 30)]['Age'].count()
print(f'Count of customers Age between 20 to 30 is: {age_20_30}')

# Percentage of customers with Age betweem 20s and 30s among all customers
percentage_age_20_30 = (age_20_30 / total_customers) * 100
print(f'Percentage of customers with Age betweem 20s and 30s among all customers is: {percentage_age_20_30:.2f}%')

display(HTML("<b>Product - Income:</b>"))
# Count of low-income customers
low_income = data[data['Income'] < 44058]['Income'].count()
print(f'Low income customers count is: {low_income}')

# Percentage of low-income customers purchasing a treadmill is
percenatge_low_income = ( low_income / total_customers) * 100
print(f'Percentage of low-income customers purchasing a treadmill is: {percenatge_low_income:.2f}%')

# Count of high-income customers
high_income = data[data['Income'] > 58668]['Income'].count()
print(f'\nHigh income customers count is: {high_income}')

# Count of High income customers purchasing KP781 treadmill
high_income_kp781 = data[(data['Income'] > 58668) & (data['Product'] == 'KP781')]['Income'].count()
print(f'High income customers purchasing KP781 treadmill count is: {high_income_kp781}')

# Percentage of high-income customers purchasing KP781 treadmill
percentage_high_income_kp781 = (high_income_kp781 / total_customers) * 100
print(f'Percentage of a high-income customers purchasing KP781 treadmill is: {percentage_high_income_kp781:.2f}%')

display(HTML("<b>Product - Fitness:</b>"))
# Count of Fitness level 5
count_fitness_5 = data[data['Fitness'] == 5]['Fitness'].count()
print(f'Count of Fitness level 5 is: {count_fitness_5}')

# Percentage of customers that have Fitness level 5
percentage_fitness_5 = (count_fitness_5 / total_customers) * 100
print(f'Percentage of customers that have Fitness level 5 is: {percentage_fitness_5:.2f}%')

# Count of Fitness level 5 purchasing KP781 treadmill
count_fitness_5_kp781 = data[(data['Fitness'] == 5) & (data['Product'] == 'KP781')]['Fitness'].count()
print(f'\nCount of Fitness level 5 purchasing KP781 treadmill is: {count_fitness_5_kp781}')

# Percentage of a customers with Fitness level 5 purchasing Kp781 treadmill
percenatge_fitness_5_kp781 = (count_fitness_5_kp781 / total_customers) * 100
print(f'Percentage of a customers with Fitness level 5 purchasing Kp781 treadmill is: {percenatge_fitness_5_kp781:.2f}%')

display(HTML("<b>Product - Martial Status:</b>"))
# Count of Partnered customers
count_partnered = data[data['MaritalStatus'] == 'Partnered']['MaritalStatus'].count()
print(f'Count of Partnered customers is: {count_partnered}')

# Percentage of a customers who are Partnered using treadmill
percenatage_partnered = (count_partnered / total_customers) * 100
print(f'Percentage of a customers who are Partnered using treadmill is: {percenatage_partnered:.2f}%')
# Out:
# <b>Product - Gender:</b>
# Total number of customers is: 180
#
# The count of Male customers is: 104
# The percentage of Male customers purchasing a treadmill is: 57.78%
#
# The count of female purchasing KP781 treadmill is: 7
# The percentage of Female customers purchasing a KP781 treadmill is: 3.89%
#
# The total no of pruchasing KP281 treadmill is: 80
# The count of Female purchasing KP281 treadmill is: 40
# The probablity of a customer being a Female given that product is KP281 is: 0.50
# <b>Product - Age:</b>
# Count of customers Age between 20 to 30 is: 115
# Percentage of customers with Age betweem 20s and 30s among all customers is: 63.89%
# <b>Product - Income:</b>
# Low income customers count is: 45
# Percentage of low-income customers purchasing a treadmill is: 25.00%
#
# High income customers count is: 45
# High income customers purchasing KP781 treadmill count is: 29
# Percentage of a high-income customers purchasing KP781 treadmill is: 16.11%
# ...

# %% [markdown]
# ***# Create frequency tables and calculate the percentage as follows***

# %%
from IPython.core.display import display, HTML
# Frequency Table for Gender vs Product
freq_table_gender = pd.crosstab(data['Gender'], data['Product'])
percentage_table_gender = pd.crosstab(data['Gender'], data['Product'], normalize='index') * 100

# Frequency Table for Age Groups
data['AgeGroup'] = pd.cut(data['Age'], bins=[0, 19, 30, 40, 50, 60, 100], labels=['<20', '20-30', '31-40', '41-50', '51-60', '60+'])
freq_table_age = pd.crosstab(data['AgeGroup'], data['Product'])
percentage_table_age = pd.crosstab(data['AgeGroup'], data['Product'], normalize='index') * 100

# Frequency Table for Income Groups
data['IncomeGroup'] = pd.cut(data['Income'], bins=[0, 44057, 58668, data['Income'].max()], labels=['Low', 'Medium', 'High'])
freq_table_income = pd.crosstab(data['IncomeGroup'], data['Product'])
percentage_table_income = pd.crosstab(data['IncomeGroup'], data['Product'], normalize='index') * 100

# Frequency Table for Fitness Level
freq_table_fitness = pd.crosstab(data['Fitness'], data['Product'])
percentage_table_fitness = pd.crosstab(data['Fitness'], data['Product'], normalize='index') * 100

# Frequency Table for Marital Status
freq_table_marital = pd.crosstab(data['MaritalStatus'], data['Product'])
percentage_table_marital = pd.crosstab(data['MaritalStatus'], data['Product'], normalize='index') * 100

display(HTML("<b>Product - Gender:</b>"))
print("Frequency Table - Gender vs Product:\n", freq_table_gender)
print("\nPercentage Table - Gender vs Product:\n", percentage_table_gender)

display(HTML("<b>Product - Age:</b>"))
print("Frequency Table - Age vs Product:\n", freq_table_age)
print("\nPercentage Table - Age vs Product:\n", percentage_table_age)

display(HTML("<b>Product - Income:</b>"))
print("Frequency Table - Income vs Product:\n", freq_table_income)
print("\nPercentage Table - Income vs Product:\n", percentage_table_income)

display(HTML("<b>Product - Fitness:</b>"))
print("Frequency Table - Fitness vs Product:\n", freq_table_fitness)
print("\nPercentage Table - Fitness vs Product:\n", percentage_table_fitness)

display(HTML("<b>Product - Martial Status:</b>"))
print("Frequency Table - Marital Status vs Product:\n", freq_table_marital)
print("\nPercentage Table - Marital Status vs Product:\n", percentage_table_marital)
# Out:
# <b>Product - Gender:</b>
# Frequency Table - Gender vs Product:
#  Product  KP281  KP481  KP781
# Gender
# Female      40     29      7
# Male        40     31     33
#
# Percentage Table - Gender vs Product:
#  Product      KP281      KP481      KP781
# Gender
# Female   52.631579  38.157895   9.210526
# Male     38.461538  29.807692  31.730769
# <b>Product - Age:</b>
# Frequency Table - Age vs Product:
#  Product   KP281  KP481  KP781
# AgeGroup
# <20           4      1      0
# 20-30        51     34     30
# 31-40        19     23      6
# 41-50         6      2      4
#
# Percentage Table - Age vs Product:
#  Product       KP281      KP481      KP781
# AgeGroup
# <20       80.000000  20.000000   0.000000
# 20-30     44.347826  29.565217  26.086957
# 31-40     39.583333  47.916667  12.500000
# 41-50     50.000000  16.666667  33.333333
# <b>Product - Income:</b>
# Frequency Table - Income vs Product:
#  Product      KP281  KP481  KP781
# IncomeGroup
# ...

# %% [markdown]
# ***Actionable Insights & Recommendations***
#
# 1. Customer Demographics & Buying Behavior
# **Insights:**
#
# - Majority of the customers belong to the age group of 20s and 30s.
# - The purchase rate of KP281, KP481, and KP781 is too lower compared to other products.
# - High-income customers (salary > 70,000) contribute a specific percentage of total treadmill purchases, but their engagement with KP781 is relatively low.
#
# **Recommendations:**
# - Targeted Marketing: Since customers in their 20s and 30s are more active buyers, they were not focused with the advertising campaigns rather than focusing on fitness benefits for this age group.
# - Product Bundling: To boost sales of KP281, KP481, and KP781, introduce discounts, EMI options, or bundle deals with accessories.
# - Income-Based Offers: Provide premium plans or discounts for high-income customers to increase engagement with KP781.
#
# 2. Correlation Analysis & Customer Preferences
# **Insights:**
#
# - Strong correlation observed between age and product preference (younger customers prefer budget-friendly options).
# - Weak correlation between income and purchase (high-income customers do not necessarily buy more expensive treadmills).
#
# **Recommendations:**
# - Age-Based Personalization: Introduce personalized product suggestions based on customer demographics.
# - Luxury Features for High-Income Groups: Since high-income customers are not buying KP781 frequently, enhance premium features (e.g., smart fitness tracking, extended warranty, or VIP membership).
#
# 3. Outlier Analysis & Data Quality
#
# **Insights:**
# - Presence of outliers in income and age suggests potential data entry errors or niche customer segments.
# - Some customers have exceptionally high salaries but do not purchase high-end treadmills.
#
# **Recommendations:**
# - Data Cleaning: Ensure consistent data formatting and remove anomalies affecting analysis.
# - Special Offers for Niche Segments: If outliers represent niche segments (e.g., older or ultra-high-income individuals), design exclusive marketing strategies for them.
#
# 4. Sales Performance & Product Positioning
# **Insights:**
#
# - KP281 and KP481 have higher sales volume, but KP781 apparently had less.
# Certain income groups prefer specific treadmill models.
# Recommendations:
# - Reposition of KP781: Promote KP781 using premium branding strategies such as influencer marketing or high-end fitness endorsements.
# - Competitive Pricing Adjustments: Analyze whether price adjustments or installment-based purchases can improve high-ticket product sales.
